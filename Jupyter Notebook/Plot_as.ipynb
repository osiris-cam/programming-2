# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
dias_x = ['Juan', 'Osiris', 'Isabel', 'Victor', 'Karen', 'Jennifer', 'Hector']
calorias_1w = [500, 200, 100, 350, 400, 150, 1000]
plt.plot(dias_x, calorias_1w, 'r--', marker= 'X', label='Week1')

calorias_2w = [100, 750, 1000, 100, 300, 50, 260]
plt.plot(dias_x, calorias_2w, 'b', marker= '*', label='Week2')

calorias_3w = [80, 100, 570, 237, 500, 100, 0]
plt.plot(dias_x, calorias_3w, 'k-.', marker= 'o', label='Week3')


plt.legend()
plt.title("Calorias quemadas en 3 semanas")
plt.xlabel("Participantes")
plt.ylabel("Calorias")
plt.show()
